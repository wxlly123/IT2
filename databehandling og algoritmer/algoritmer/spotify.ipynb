# %%
print("Hallo, verden!")
# Out:
# Hallo, verden!

# %%
import json
with open("spotify-weekly-top-songs-global-uke2-2023.json") as fil:
    data = json.load(fil)
data
# Out:
# [{'navn': 'La Diabla',
#   'artist': 'Xavi',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e021501c770de50a22b25d67611',
#   'plassering': 1,
#   'forrige_plassering': 1,
#   'topplassering': 1,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 5,
#   'antall_streams': 34195950},
#  {'navn': 'greedy',
#   'artist': 'Tate McRae',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0222fd802bc61db666c7c81aa8',
#   'plassering': 2,
#   'forrige_plassering': 2,
#   'topplassering': 1,
#   'topp_dato': '2023-11-16',
#   'uker_paa_listen': 17,
#   'antall_streams': 34059012},
#  {'navn': 'Lovin On Me',
#   'artist': 'Jack Harlow',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02fcf4adae77baba5d0169e8e8',
#   'plassering': 3,
#   'forrige_plassering': 3,
#   'topplassering': 3,
#   'topp_dato': '2024-01-04',
#   'uker_paa_listen': 9,
#   'antall_streams': 32055608},
#  {'navn': 'Cruel Summer',
#   'artist': 'Taylor Swift',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e787cffec20aa2a396a61647',
#   'plassering': 4,
#   'forrige_plassering': 4,
#   'topplassering': 2,
#   'topp_dato': '2023-07-06',
#   'uker_paa_listen': 49,
#   'antall_streams': 28511866},
#  {'navn': 'One Of The Girls (with JENNIE, Lily Rose Depp)',
#   'artist': 'The Weeknd',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02b0dd6a5cd1dec96c4119c262',
#   'plassering': 5,
#   'forrige_plassering': 5,
#   'topplassering': 5,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 14,
#   'antall_streams': 27400991},
#  {'navn': 'My Love Mine All Mine',
#   'artist': 'Mitski',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0234f21d3047d85440dfa37f10',
#   'plassering': 6,
#   'forrige_plassering': 6,
#   'topplassering': 3,
#   'topp_dato': '2023-11-23',
#   'uker_paa_listen': 16,
#   'antall_streams': 27354041},
#  {'navn': 'Stick Season',
#   'artist': 'Noah Kahan',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e026ee35072df1af802cca09918',
#   'plassering': 7,
#   'forrige_plassering': 7,
#   'topplassering': 7,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 14,
#   'antall_streams': 24788155},
#  {'navn': 'La Víctima',
#   'artist': 'Xavi',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e020e8dc9720dd03d86627fa54b',
#   'plassering': 8,
#   'forrige_plassering': 8,
#   'topplassering': 8,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 7,
#   'antall_streams': 23066551},
#  {'navn': 'Seven (feat. Latto) (Explicit Ver.)',
#   'artist': 'Jung Kook',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02741fd4807f442af3f7359316',
#   'plassering': 9,
#   'forrige_plassering': 9,
#   'topplassering': 1,
#   'topp_dato': '2023-07-20',
#   'uker_paa_listen': 26,
#   'antall_streams': 22294951},
#  {'navn': 'Paint The Town Red',
#   'artist': 'Doja Cat',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02a840032f14ab22da396e43cb',
#   'plassering': 10,
#   'forrige_plassering': 10,
#   'topplassering': 1,
#   'topp_dato': '2023-09-14',
#   'uker_paa_listen': 23,
#   'antall_streams': 22034792},
#  {'navn': 'LUNA',
#   'artist': 'Feid',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02f1aad814a40ec7419c234242',
#   'plassering': 11,
#   'forrige_plassering': 11,
#   'topplassering': 11,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 5,
#   'antall_streams': 21652729},
#  {'navn': 'BELLAKEO',
#   'artist': 'Peso Pluma',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e026601556a0f7c0b54ded13c9d',
#   'plassering': 12,
#   'forrige_plassering': 12,
#   'topplassering': 10,
#   'topp_dato': '2024-01-04',
#   'uker_paa_listen': 5,
#   'antall_streams': 20997062},
#  {'navn': 'Popular (with Playboi Carti & Madonna) - Music from the HBO Original Series',
#   'artist': 'The Weeknd',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e024c8f092adc59b4bf4212389d',
#   'plassering': 13,
#   'forrige_plassering': 13,
#   'topplassering': 13,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 32,
#   'antall_streams': 20428615},
#  {'navn': 'Strangers',
#   'artist': 'Kenya Grace',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e024756c2e9ae436437cd75e9f3',
#   'plassering': 14,
#   'forrige_plassering': 14,
#   'topplassering': 4,
#   'topp_dato': '2023-09-28',
#   'uker_paa_listen': 19,
#   'antall_streams': 20024519},
#  {'navn': 'I Wanna Be Yours',
#   'artist': 'Arctic Monkeys',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e024ae1c4c5c45aabe565499163',
#   'plassering': 15,
#   'forrige_plassering': 15,
#   'topplassering': 15,
#   'topp_dato': '2023-09-28',
#   'uker_paa_listen': 79,
#   'antall_streams': 19970377},
#  {'navn': 'Water',
#   'artist': 'Tyla',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02d20231861e86a6f74ef2393e',
#   'plassering': 16,
#   'forrige_plassering': 16,
#   'topplassering': 12,
#   'topp_dato': '2023-10-26',
#   'uker_paa_listen': 16,
#   'antall_streams': 19677995},
#  {'navn': 'PERRO NEGRO',
#   'artist': 'Bad Bunny',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e027b1fc51ff3257b5286a1ecec',
#   'plassering': 17,
#   'forrige_plassering': 17,
#   'topplassering': 4,
#   'topp_dato': '2023-10-19',
#   'uker_paa_listen': 13,
#   'antall_streams': 19476456},
#  {'navn': 'Standing Next to You',
#   'artist': 'Jung Kook',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02741fd4807f442af3f7359316',
#   'plassering': 18,
#   'forrige_plassering': 18,
#   'topplassering': 1,
#   'topp_dato': '2023-11-09',
#   'uker_paa_listen': 10,
#   'antall_streams': 19381222},
#  {'navn': 'QLONA',
#   'artist': 'KAROL G',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02d026bf9d7780f6a1267b4d03',
#   'plassering': 19,
#   'forrige_plassering': 19,
#   'topplassering': 5,
#   'topp_dato': '2023-09-07',
#   'uker_paa_listen': 22,
#   'antall_streams': 18450452},
#  {'navn': 'vampire',
#   'artist': 'Olivia Rodrigo',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e85259a1cae29a8d91f2093d',
#   'plassering': 20,
#   'forrige_plassering': 20,
#   'topplassering': 1,
#   'topp_dato': '2023-07-06',
#   'uker_paa_listen': 28,
#   'antall_streams': 18230348},
#  {'navn': 'Que Onda',
#   'artist': 'Calle 24',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02c8fd4190e32eed2dfcd00f66',
#   'plassering': 21,
#   'forrige_plassering': 21,
#   'topplassering': 16,
#   'topp_dato': '2023-10-26',
#   'uker_paa_listen': 19,
#   'antall_streams': 17356851},
#  {'navn': 'Agora Hills',
#   'artist': 'Doja Cat',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02a840032f14ab22da396e43cb',
#   'plassering': 22,
#   'forrige_plassering': 22,
#   'topplassering': 16,
#   'topp_dato': '2023-11-23',
#   'uker_paa_listen': 16,
#   'antall_streams': 17152621},
#  {'navn': 'Starboy',
#   'artist': 'The Weeknd',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e024718e2b124f79258be7bc452',
#   'plassering': 23,
#   'forrige_plassering': 23,
#   'topplassering': 1,
#   'topp_dato': '2016-12-29',
#   'uker_paa_listen': 171,
#   'antall_streams': 17100327},
#  {'navn': 'Si No Estás',
#   'artist': 'iñigo quintero',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e025cb9531348f45311cd6fb8df',
#   'plassering': 24,
#   'forrige_plassering': 24,
#   'topplassering': 1,
#   'topp_dato': '2023-10-26',
#   'uker_paa_listen': 16,
#   'antall_streams': 17002985},
#  {'navn': 'HARLEY QUINN',
#   'artist': 'Fuerza Regida',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02ad57982065339f7dc2058efe',
#   'plassering': 25,
#   'forrige_plassering': 25,
#   'topplassering': 11,
#   'topp_dato': '2023-11-23',
#   'uker_paa_listen': 11,
#   'antall_streams': 16758491},
#  {'navn': 'What Was I Made For? [From The Motion Picture "Barbie"]',
#   'artist': 'Billie Eilish',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02ed317ec13d3de9e01fb99c9e',
#   'plassering': 26,
#   'forrige_plassering': 26,
#   'topplassering': 3,
#   'topp_dato': '2023-08-10',
#   'uker_paa_listen': 26,
#   'antall_streams': 16646305},
#  {'navn': 'Kill Bill',
#   'artist': 'SZA',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e020c471c36970b9406233842a5',
#   'plassering': 27,
#   'forrige_plassering': 27,
#   'topplassering': 1,
#   'topp_dato': '2023-01-05',
#   'uker_paa_listen': 57,
#   'antall_streams': 16398834},
#  {'navn': 'As It Was',
#   'artist': 'Harry Styles',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e022e8ed79e177ff6011076f5f0',
#   'plassering': 28,
#   'forrige_plassering': 28,
#   'topplassering': 1,
#   'topp_dato': '2022-04-07',
#   'uker_paa_listen': 93,
#   'antall_streams': 15967765},
#  {'navn': 'Daylight',
#   'artist': 'David Kushner',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0295ca6a9b4083a86c149934ae',
#   'plassering': 29,
#   'forrige_plassering': 29,
#   'topplassering': 5,
#   'topp_dato': '2023-04-27',
#   'uker_paa_listen': 39,
#   'antall_streams': 15821912},
#  {'navn': 'Riptide',
#   'artist': 'Vance Joy',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02d3ce97395ff522b0d70c1094',
#   'plassering': 30,
#   'forrige_plassering': 30,
#   'topplassering': 30,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 152,
#   'antall_streams': 15744110},
#  {'navn': 'Houdini',
#   'artist': 'Dua Lipa',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02001d5706fddc72561f6488af',
#   'plassering': 31,
#   'forrige_plassering': 31,
#   'topplassering': 6,
#   'topp_dato': '2023-11-16',
#   'uker_paa_listen': 9,
#   'antall_streams': 15642294},
#  {'navn': 'Lose Control',
#   'artist': 'Teddy Swims',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e021a0323cc23419360a34a3ace',
#   'plassering': 32,
#   'forrige_plassering': 32,
#   'topplassering': 32,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 9,
#   'antall_streams': 15462408},
#  {'navn': 'Murder On The Dancefloor',
#   'artist': 'Sophie Ellis-Bextor',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02b736151ed1c04f2d41d5f69e',
#   'plassering': 33,
#   'forrige_plassering': 33,
#   'topplassering': 33,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 2,
#   'antall_streams': 15428131},
#  {'navn': 'Surround Sound (feat. 21 Savage & Baby Tate)',
#   'artist': 'JID',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02cae6e44dcc84e2035c3ad092',
#   'plassering': 34,
#   'forrige_plassering': 34,
#   'topplassering': 34,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 8,
#   'antall_streams': 14786989},
#  {'navn': 'Según Quién',
#   'artist': 'Maluma',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02d688b951a19f48941682e026',
#   'plassering': 35,
#   'forrige_plassering': 35,
#   'topplassering': 17,
#   'topp_dato': '2023-10-26',
#   'uker_paa_listen': 17,
#   'antall_streams': 14701296},
#  {'navn': 'I Remember Everything (feat. Kacey Musgraves)',
#   'artist': 'Zach Bryan',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e5a25ed08d1e7e0fbb440cef',
#   'plassering': 36,
#   'forrige_plassering': 36,
#   'topplassering': 20,
#   'topp_dato': '2023-09-07',
#   'uker_paa_listen': 20,
#   'antall_streams': 14698793},
#  {'navn': 'Prada',
#   'artist': 'cassö',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e4b7dccdfd54375ded9ccc5c',
#   'plassering': 37,
#   'forrige_plassering': 37,
#   'topplassering': 17,
#   'topp_dato': '2023-09-28',
#   'uker_paa_listen': 21,
#   'antall_streams': 14550323},
#  {'navn': 'Flowers',
#   'artist': 'Miley Cyrus',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02cd222052a2594be29a6616b5',
#   'plassering': 38,
#   'forrige_plassering': 38,
#   'topplassering': 1,
#   'topp_dato': '2023-01-19',
#   'uker_paa_listen': 52,
#   'antall_streams': 14548483},
#  {'navn': 'The Night We Met',
#   'artist': 'Lord Huron',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0217875a0610c23d8946454583',
#   'plassering': 39,
#   'forrige_plassering': 39,
#   'topplassering': 36,
#   'topp_dato': '2023-11-23',
#   'uker_paa_listen': 64,
#   'antall_streams': 14442070},
#  {'navn': 'Die For You',
#   'artist': 'The Weeknd',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02a048415db06a5b6fa7ec4e1a',
#   'plassering': 40,
#   'forrige_plassering': 40,
#   'topplassering': 12,
#   'topp_dato': '2023-02-23',
#   'uker_paa_listen': 100,
#   'antall_streams': 14241827},
#  {'navn': 'Dance The Night - From Barbie The Album',
#   'artist': 'Dua Lipa',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e027dd3ba455ee3390cb55b0192',
#   'plassering': 41,
#   'forrige_plassering': 41,
#   'topplassering': 5,
#   'topp_dato': '2023-08-10',
#   'uker_paa_listen': 33,
#   'antall_streams': 14191744},
#  {'navn': 'Snooze',
#   'artist': 'SZA',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0270dbc9f47669d120ad874ec1',
#   'plassering': 42,
#   'forrige_plassering': 42,
#   'topplassering': 32,
#   'topp_dato': '2023-02-16',
#   'uker_paa_listen': 55,
#   'antall_streams': 14106335},
#  {'navn': '3D (feat. Jack Harlow)',
#   'artist': 'Jung Kook',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0299583bb32b47e87d55c6064b',
#   'plassering': 43,
#   'forrige_plassering': 43,
#   'topplassering': 3,
#   'topp_dato': '2023-10-05',
#   'uker_paa_listen': 15,
#   'antall_streams': 13877871},
#  {'navn': 'Sweater Weather',
#   'artist': 'The Neighbourhood',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e028265a736a1eb838ad5a0b921',
#   'plassering': 44,
#   'forrige_plassering': 44,
#   'topplassering': 19,
#   'topp_dato': '2022-10-20',
#   'uker_paa_listen': 176,
#   'antall_streams': 13859103},
#  {'navn': 'Blinding Lights',
#   'artist': 'The Weeknd',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#   'plassering': 45,
#   'forrige_plassering': 45,
#   'topplassering': 1,
#   'topp_dato': '2020-02-27',
#   'uker_paa_listen': 215,
#   'antall_streams': 13651163},
#  {'navn': 'LALA',
#   'artist': 'Myke Towers',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e020656d5ce813ca3cc4b677e05',
#   'plassering': 46,
#   'forrige_plassering': 46,
#   'topplassering': 1,
#   'topp_dato': '2023-07-13',
#   'uker_paa_listen': 28,
#   'antall_streams': 13507364},
#  {'navn': 'Feather',
#   'artist': 'Sabrina Carpenter',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e020f45623be014a592a5815827',
#   'plassering': 47,
#   'forrige_plassering': 47,
#   'topplassering': 47,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 6,
#   'antall_streams': 13391680},
#  {'navn': 'MONACO',
#   'artist': 'Bad Bunny',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e027b1fc51ff3257b5286a1ecec',
#   'plassering': 48,
#   'forrige_plassering': 48,
#   'topplassering': 1,
#   'topp_dato': '2023-10-19',
#   'uker_paa_listen': 13,
#   'antall_streams': 13295708},
#  {'navn': 'Love Me Again',
#   'artist': 'V',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e022f1a5b69c2bd76474bca8035',
#   'plassering': 49,
#   'forrige_plassering': 49,
#   'topplassering': 11,
#   'topp_dato': '2023-08-17',
#   'uker_paa_listen': 22,
#   'antall_streams': 13206831},
#  {'navn': 'Rompe La Dompe',
#   'artist': 'Peso Pluma',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02a7a330bed7c3b2217e3be9a8',
#   'plassering': 50,
#   'forrige_plassering': 50,
#   'topplassering': 38,
#   'topp_dato': '2024-01-04',
#   'uker_paa_listen': 2,
#   'antall_streams': 13122143},
#  {'navn': "Is It Over Now? (Taylor's Version) (From The Vault)",
#   'artist': 'Taylor Swift',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02904445d70d04eb24d6bb79ac',
#   'plassering': 51,
#   'forrige_plassering': 51,
#   'topplassering': 1,
#   'topp_dato': '2023-11-02',
#   'uker_paa_listen': 11,
#   'antall_streams': 13020606},
#  {'navn': 'Rich Baby Daddy (feat. Sexyy Red & SZA)',
#   'artist': 'Drake',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e027d384516b23347e92a587ed1',
#   'plassering': 52,
#   'forrige_plassering': 52,
#   'topplassering': 28,
#   'topp_dato': '2023-10-12',
#   'uker_paa_listen': 13,
#   'antall_streams': 13017598},
#  {'navn': 'EL AMOR DE SU VIDA',
#   'artist': 'Grupo Frontera',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0282ce4c7bbf861185252e82ae',
#   'plassering': 53,
#   'forrige_plassering': 53,
#   'topplassering': 47,
#   'topp_dato': '2024-01-04',
#   'uker_paa_listen': 23,
#   'antall_streams': 12919864},
#  {'navn': 'Another Love',
#   'artist': 'Tom Odell',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e021917a0f3f4152622a040913f',
#   'plassering': 54,
#   'forrige_plassering': 54,
#   'topplassering': 15,
#   'topp_dato': '2022-10-13',
#   'uker_paa_listen': 144,
#   'antall_streams': 12882699},
#  {'navn': 'See You Again (feat. Kali Uchis)',
#   'artist': 'Tyler, The Creator',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e028940ac99f49e44f59e6f7fb3',
#   'plassering': 55,
#   'forrige_plassering': 55,
#   'topplassering': 16,
#   'topp_dato': '2023-05-18',
#   'uker_paa_listen': 46,
#   'antall_streams': 12624432},
#  {'navn': 'fukumean',
#   'artist': 'Gunna',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02017d5e26552345c4b1575b6c',
#   'plassering': 56,
#   'forrige_plassering': 56,
#   'topplassering': 9,
#   'topp_dato': '2023-07-20',
#   'uker_paa_listen': 30,
#   'antall_streams': 12504254},
#  {'navn': 'Columbia',
#   'artist': 'Quevedo',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02a00a817b017c6f6bf8460be9',
#   'plassering': 57,
#   'forrige_plassering': 57,
#   'topplassering': 7,
#   'topp_dato': '2023-08-24',
#   'uker_paa_listen': 27,
#   'antall_streams': 12227913},
#  {'navn': 'exes',
#   'artist': 'Tate McRae',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0277eb7a5b9367de79c3b92a49',
#   'plassering': 58,
#   'forrige_plassering': 58,
#   'topplassering': 26,
#   'topp_dato': '2023-11-23',
#   'uker_paa_listen': 8,
#   'antall_streams': 12153251},
#  {'navn': 'LADY GAGA',
#   'artist': 'Peso Pluma',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e022fb583ed96f8f35cbf2897ba',
#   'plassering': 59,
#   'forrige_plassering': 59,
#   'topplassering': 9,
#   'topp_dato': '2023-06-29',
#   'uker_paa_listen': 29,
#   'antall_streams': 12094395},
#  {'navn': 'Like Crazy',
#   'artist': 'Jimin',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e022b46078245d0120690eb560d',
#   'plassering': 60,
#   'forrige_plassering': 60,
#   'topplassering': 15,
#   'topp_dato': '2023-03-30',
#   'uker_paa_listen': 42,
#   'antall_streams': 12091523},
#  {'navn': "I'm Good (Blue)",
#   'artist': 'David Guetta',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02933c036cd61cd40d3f17a9c4',
#   'plassering': 61,
#   'forrige_plassering': 61,
#   'topplassering': 2,
#   'topp_dato': '2022-09-29',
#   'uker_paa_listen': 72,
#   'antall_streams': 12082598},
#  {'navn': 'IDGAF (feat. Yeat)',
#   'artist': 'Drake',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e027d384516b23347e92a587ed1',
#   'plassering': 62,
#   'forrige_plassering': 62,
#   'topplassering': 5,
#   'topp_dato': '2023-10-12',
#   'uker_paa_listen': 14,
#   'antall_streams': 11933338},
#  {'navn': 'FTCU',
#   'artist': 'Nicki Minaj',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02651e1dbc0b5218f2306181a1',
#   'plassering': 63,
#   'forrige_plassering': 63,
#   'topplassering': 63,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 4,
#   'antall_streams': 11892608},
#  {'navn': 'Lover',
#   'artist': 'Taylor Swift',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e787cffec20aa2a396a61647',
#   'plassering': 64,
#   'forrige_plassering': 64,
#   'topplassering': 2,
#   'topp_dato': '2019-08-29',
#   'uker_paa_listen': 49,
#   'antall_streams': 11885974},
#  {'navn': 'Anti-Hero',
#   'artist': 'Taylor Swift',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02bb54dde68cd23e2a268ae0f5',
#   'plassering': 65,
#   'forrige_plassering': 65,
#   'topplassering': 1,
#   'topp_dato': '2022-10-27',
#   'uker_paa_listen': 64,
#   'antall_streams': 11756777},
#  {'navn': 'Sunflower - Spider-Man: Into the Spider-Verse',
#   'artist': 'Post Malone',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e029478c87599550dd73bfa7e02',
#   'plassering': 66,
#   'forrige_plassering': 66,
#   'topplassering': 1,
#   'topp_dato': '2019-01-10',
#   'uker_paa_listen': 266,
#   'antall_streams': 11536228},
#  {'navn': 'I KNOW ?',
#   'artist': 'Travis Scott',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02881d8d8378cd01099babcd44',
#   'plassering': 67,
#   'forrige_plassering': 67,
#   'topplassering': 14,
#   'topp_dato': '2023-08-03',
#   'uker_paa_listen': 24,
#   'antall_streams': 11483082},
#  {'navn': 'un x100to',
#   'artist': 'Grupo Frontera',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0282ce4c7bbf861185252e82ae',
#   'plassering': 68,
#   'forrige_plassering': 68,
#   'topplassering': 1,
#   'topp_dato': '2023-05-04',
#   'uker_paa_listen': 39,
#   'antall_streams': 11455676},
#  {'navn': 'Calm Down (with Selena Gomez)',
#   'artist': 'Rema',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02963265801aa5c9740ad159b7',
#   'plassering': 69,
#   'forrige_plassering': 69,
#   'topplassering': 9,
#   'topp_dato': '2023-02-02',
#   'uker_paa_listen': 72,
#   'antall_streams': 11425736},
#  {'navn': "I Ain't Worried",
#   'artist': 'OneRepublic',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02ec96e006b8bdfc582610ec13',
#   'plassering': 70,
#   'forrige_plassering': 70,
#   'topplassering': 7,
#   'topp_dato': '2022-09-15',
#   'uker_paa_listen': 84,
#   'antall_streams': 11381598},
#  {'navn': 'Can’t Catch Me Now - from The Hunger Games: The Ballad of Songbirds & Snakes',
#   'artist': 'Olivia Rodrigo',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0222ad9f1afdbeeceaf0c91686',
#   'plassering': 71,
#   'forrige_plassering': 71,
#   'topplassering': 35,
#   'topp_dato': '2023-11-30',
#   'uker_paa_listen': 10,
#   'antall_streams': 11281453},
#  {'navn': 'Yellow',
#   'artist': 'Coldplay',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e023d92b2ad5af9fbc8637425f0',
#   'plassering': 72,
#   'forrige_plassering': 72,
#   'topplassering': 50,
#   'topp_dato': '2023-05-25',
#   'uker_paa_listen': 160,
#   'antall_streams': 11202544},
#  {'navn': 'Pehle Bhi Main',
#   'artist': 'Vishal Mishra',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e025f3ede47954a93aa03efe5f9',
#   'plassering': 73,
#   'forrige_plassering': 73,
#   'topplassering': 49,
#   'topp_dato': '2023-12-14',
#   'uker_paa_listen': 5,
#   'antall_streams': 11194555},
#  {'navn': 'Viva La Vida',
#   'artist': 'Coldplay',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e21cc1db05580b6f2d2a3b6e',
#   'plassering': 74,
#   'forrige_plassering': 74,
#   'topplassering': 57,
#   'topp_dato': '2023-05-18',
#   'uker_paa_listen': 72,
#   'antall_streams': 10985760},
#  {'navn': 'Someone You Loved',
#   'artist': 'Lewis Capaldi',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02fc2101e6889d6ce9025f85f2',
#   'plassering': 75,
#   'forrige_plassering': 75,
#   'topplassering': 4,
#   'topp_dato': '2019-10-03',
#   'uker_paa_listen': 261,
#   'antall_streams': 10958351},
#  {'navn': 'Heartless',
#   'artist': 'Kanye West',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02346d77e155d854735410ed18',
#   'plassering': 76,
#   'forrige_plassering': 76,
#   'topplassering': 76,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 27,
#   'antall_streams': 10832805},
#  {'navn': 'Primera Cita',
#   'artist': 'Carin Leon',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e020e30fcf494fd711ad068d1cd',
#   'plassering': 77,
#   'forrige_plassering': 77,
#   'topplassering': 21,
#   'topp_dato': '2023-09-28',
#   'uker_paa_listen': 28,
#   'antall_streams': 10786386},
#  {'navn': 'Y LLORO',
#   'artist': 'Junior H',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02f3ba6742a35f111aaea1ca2f',
#   'plassering': 78,
#   'forrige_plassering': 78,
#   'topplassering': 55,
#   'topp_dato': '2023-10-26',
#   'uker_paa_listen': 14,
#   'antall_streams': 10748250},
#  {'navn': "Creepin' (with The Weeknd & 21 Savage)",
#   'artist': 'Metro Boomin',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02c4fee55d7b51479627c31f89',
#   'plassering': 79,
#   'forrige_plassering': 79,
#   'topplassering': 2,
#   'topp_dato': '2023-01-12',
#   'uker_paa_listen': 58,
#   'antall_streams': 10722369},
#  {'navn': 'Locked out of Heaven',
#   'artist': 'Bruno Mars',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02926f43e7cce571e62720fd46',
#   'plassering': 80,
#   'forrige_plassering': 80,
#   'topplassering': 39,
#   'topp_dato': '2023-09-28',
#   'uker_paa_listen': 83,
#   'antall_streams': 10654137},
#  {'navn': 'Apocalypse',
#   'artist': 'Cigarettes After Sex',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0212b69bf576f5e80291f75161',
#   'plassering': 81,
#   'forrige_plassering': 81,
#   'topplassering': 81,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 78,
#   'antall_streams': 10623414},
#  {'navn': 'One Dance',
#   'artist': 'Drake',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e029416ed64daf84936d89e671c',
#   'plassering': 82,
#   'forrige_plassering': 82,
#   'topplassering': 12,
#   'topp_dato': '2017-01-05',
#   'uker_paa_listen': 176,
#   'antall_streams': 10612953},
#  {'navn': 'CLASSY 101',
#   'artist': 'Feid',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02f1aad814a40ec7419c234242',
#   'plassering': 83,
#   'forrige_plassering': 83,
#   'topplassering': 8,
#   'topp_dato': '2023-04-27',
#   'uker_paa_listen': 41,
#   'antall_streams': 10595752},
#  {'navn': 'FE!N (feat. Playboi Carti)',
#   'artist': 'Travis Scott',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02881d8d8378cd01099babcd44',
#   'plassering': 84,
#   'forrige_plassering': 84,
#   'topplassering': 5,
#   'topp_dato': '2023-08-03',
#   'uker_paa_listen': 17,
#   'antall_streams': 10506246},
#  {'navn': 'Poco A Poco',
#   'artist': 'Xavi',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02b79bb48c27ca9d10b784a52d',
#   'plassering': 85,
#   'forrige_plassering': 85,
#   'topplassering': 80,
#   'topp_dato': '2024-01-04',
#   'uker_paa_listen': 3,
#   'antall_streams': 10501299},
#  {'navn': 'Counting Stars',
#   'artist': 'OneRepublic',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e029e2f95ae77cf436017ada9cb',
#   'plassering': 86,
#   'forrige_plassering': 86,
#   'topplassering': 86,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 143,
#   'antall_streams': 10460240},
#  {'navn': 'Somewhere Only We Know',
#   'artist': 'Keane',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e027d6cd95a046a3c0dacbc7d33',
#   'plassering': 87,
#   'forrige_plassering': 87,
#   'topplassering': 87,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 64,
#   'antall_streams': 10401937},
#  {'navn': 'Husn',
#   'artist': 'Anuv Jain',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e020d3449f333a83a25feb423f8',
#   'plassering': 88,
#   'forrige_plassering': 88,
#   'topplassering': 88,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 2,
#   'antall_streams': 10380317},
#  {'navn': 'Without Me',
#   'artist': 'Eminem',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e026ca5c90113b30c3c43ffb8f4',
#   'plassering': 89,
#   'forrige_plassering': 89,
#   'topplassering': 31,
#   'topp_dato': '2022-02-24',
#   'uker_paa_listen': 120,
#   'antall_streams': 10374607},
#  {'navn': 'Save Your Tears',
#   'artist': 'The Weeknd',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#   'plassering': 90,
#   'forrige_plassering': 90,
#   'topplassering': 2,
#   'topp_dato': '2021-02-11',
#   'uker_paa_listen': 156,
#   'antall_streams': 10360253},
#  {'navn': 'Pink + White',
#   'artist': 'Frank Ocean',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02c5649add07ed3720be9d5526',
#   'plassering': 91,
#   'forrige_plassering': 91,
#   'topplassering': 70,
#   'topp_dato': '2023-11-30',
#   'uker_paa_listen': 34,
#   'antall_streams': 10338338},
#  {'navn': 'Stargirl Interlude',
#   'artist': 'The Weeknd',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02a048415db06a5b6fa7ec4e1a',
#   'plassering': 92,
#   'forrige_plassering': 92,
#   'topplassering': 92,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 76,
#   'antall_streams': 10320373},
#  {'navn': 'No Role Modelz',
#   'artist': 'J. Cole',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02c6e0948bbb0681ff29cdbae8',
#   'plassering': 93,
#   'forrige_plassering': 93,
#   'topplassering': 76,
#   'topp_dato': '2022-04-28',
#   'uker_paa_listen': 129,
#   'antall_streams': 10288858},
#  {'navn': 'Maria Mariah',
#   'artist': 'JC NO BEAT',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02093c36c26aab9fd3e40d3e6e',
#   'plassering': 94,
#   'forrige_plassering': 94,
#   'topplassering': 94,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 2,
#   'antall_streams': 10083665},
#  {'navn': 'cardigan',
#   'artist': 'Taylor Swift',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0295f754318336a07e85ec59bc',
#   'plassering': 95,
#   'forrige_plassering': 95,
#   'topplassering': 1,
#   'topp_dato': '2020-07-30',
#   'uker_paa_listen': 55,
#   'antall_streams': 10080740},
#  {'navn': 'La Bachata',
#   'artist': 'Manuel Turizo',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e024dd99565ae6453deab7c26e1',
#   'plassering': 96,
#   'forrige_plassering': 96,
#   'topplassering': 4,
#   'topp_dato': '2022-10-20',
#   'uker_paa_listen': 80,
#   'antall_streams': 9905660},
#  {'navn': "Why'd You Only Call Me When You're High?",
#   'artist': 'Arctic Monkeys',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e024ae1c4c5c45aabe565499163',
#   'plassering': 97,
#   'forrige_plassering': 97,
#   'topplassering': 95,
#   'topp_dato': '2023-09-21',
#   'uker_paa_listen': 109,
#   'antall_streams': 9871303},
#  {'navn': 'Alucin',
#   'artist': 'Eugenio Esquivel',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02086a84a764dc341262487967',
#   'plassering': 98,
#   'forrige_plassering': 98,
#   'topplassering': 98,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 2,
#   'antall_streams': 9848890},
#  {'navn': 'I Love You So',
#   'artist': 'The Walters',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e029214ff0109a0e062f8a6cf0f',
#   'plassering': 99,
#   'forrige_plassering': 99,
#   'topplassering': 21,
#   'topp_dato': '2022-01-27',
#   'uker_paa_listen': 87,
#   'antall_streams': 9818789},
#  {'navn': 'Lovers Rock',
#   'artist': 'TV Girl',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e1bc1af856b42dd7fdba9f84',
#   'plassering': 100,
#   'forrige_plassering': 100,
#   'topplassering': 100,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 29,
#   'antall_streams': 9816798},
#  {'navn': 'Mockingbird',
#   'artist': 'Eminem',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02726d48d93d02e1271774f023',
#   'plassering': 101,
#   'forrige_plassering': 101,
#   'topplassering': 24,
#   'topp_dato': '2022-12-01',
#   'uker_paa_listen': 65,
#   'antall_streams': 9790455},
#  {'navn': 'DILUVIO',
#   'artist': 'Rauw Alejandro',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02f79b1ab5cd74db6a2d7c1fda',
#   'plassering': 102,
#   'forrige_plassering': 102,
#   'topplassering': 59,
#   'topp_dato': '2023-11-23',
#   'uker_paa_listen': 9,
#   'antall_streams': 9750758},
#  {'navn': 'ANDO',
#   'artist': 'Jere Klein',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02c9af3d78758eaf8d896fd37c',
#   'plassering': 103,
#   'forrige_plassering': 103,
#   'topplassering': 99,
#   'topp_dato': '2024-01-04',
#   'uker_paa_listen': 6,
#   'antall_streams': 9733140},
#  {'navn': 'Perfect Night',
#   'artist': 'LE SSERAFIM',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e025e352f6eccf8cb96d0b247cc',
#   'plassering': 104,
#   'forrige_plassering': 104,
#   'topplassering': 57,
#   'topp_dato': '2023-11-16',
#   'uker_paa_listen': 11,
#   'antall_streams': 9730816},
#  {'navn': 'We Found Love',
#   'artist': 'Rihanna',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02bef074de9ca825bddaeb9f46',
#   'plassering': 105,
#   'forrige_plassering': 105,
#   'topplassering': 59,
#   'topp_dato': '2023-02-23',
#   'uker_paa_listen': 45,
#   'antall_streams': 9699289},
#  {'navn': "Can't Hold Us (feat. Ray Dalton)",
#   'artist': 'Macklemore & Ryan Lewis',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e022a6b364528b128a4a17d100d',
#   'plassering': 106,
#   'forrige_plassering': 106,
#   'topplassering': 86,
#   'topp_dato': '2023-11-23',
#   'uker_paa_listen': 100,
#   'antall_streams': 9668162},
#  {'navn': 'Something in the Orange',
#   'artist': 'Zach Bryan',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02b2b6670e3aca9bcd55fbabbb',
#   'plassering': 107,
#   'forrige_plassering': 107,
#   'topplassering': 57,
#   'topp_dato': '2022-10-20',
#   'uker_paa_listen': 53,
#   'antall_streams': 9611435},
#  {'navn': 'Moonlight',
#   'artist': 'Kali Uchis',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0281fccd758776d16b87721b17',
#   'plassering': 108,
#   'forrige_plassering': 108,
#   'topplassering': 37,
#   'topp_dato': '2023-05-18',
#   'uker_paa_listen': 44,
#   'antall_streams': 9596259},
#  {'navn': 'MY EYES',
#   'artist': 'Travis Scott',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02881d8d8378cd01099babcd44',
#   'plassering': 109,
#   'forrige_plassering': 109,
#   'topplassering': 15,
#   'topp_dato': '2023-08-03',
#   'uker_paa_listen': 9,
#   'antall_streams': 9595268},
#  {'navn': 'Don’t Blame Me',
#   'artist': 'Taylor Swift',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02da5d5aeeabacacc1263c0f4b',
#   'plassering': 110,
#   'forrige_plassering': 110,
#   'topplassering': 71,
#   'topp_dato': '2023-10-26',
#   'uker_paa_listen': 73,
#   'antall_streams': 9559692},
#  {'navn': 'Summertime Sadness',
#   'artist': 'Lana Del Rey',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02ebc8cfac8b586bc475b04918',
#   'plassering': 111,
#   'forrige_plassering': 111,
#   'topplassering': 83,
#   'topp_dato': '2023-09-28',
#   'uker_paa_listen': 74,
#   'antall_streams': 9552819},
#  {'navn': 'Shut up My Moms Calling',
#   'artist': 'Hotel Ugly',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02350ab7a839c04bfd5225a9f5',
#   'plassering': 112,
#   'forrige_plassering': 112,
#   'topplassering': 82,
#   'topp_dato': '2023-09-28',
#   'uker_paa_listen': 53,
#   'antall_streams': 9541382},
#  {'navn': 'Set Fire to the Rain',
#   'artist': 'Adele',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02164feb363334f93b6458d2a9',
#   'plassering': 113,
#   'forrige_plassering': 113,
#   'topplassering': 61,
#   'topp_dato': '2021-10-21',
#   'uker_paa_listen': 56,
#   'antall_streams': 9527515},
#  {'navn': 'You’re Losing Me (From The Vault)',
#   'artist': 'Taylor Swift',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e024fe1868aa6838eb595f3673a',
#   'plassering': 114,
#   'forrige_plassering': 114,
#   'topplassering': 14,
#   'topp_dato': '2023-12-07',
#   'uker_paa_listen': 7,
#   'antall_streams': 9520505},
#  {'navn': 'Romantic Homicide',
#   'artist': 'd4vd',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02bd1a52b3d5903ee01c216da0',
#   'plassering': 115,
#   'forrige_plassering': 115,
#   'topplassering': 17,
#   'topp_dato': '2022-10-20',
#   'uker_paa_listen': 71,
#   'antall_streams': 9503483},
#  {'navn': 'DEJA VU',
#   'artist': 'Luan Santana',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e035c09f33e2a896edef4bdb',
#   'plassering': 116,
#   'forrige_plassering': 116,
#   'topplassering': 54,
#   'topp_dato': '2024-01-04',
#   'uker_paa_listen': 3,
#   'antall_streams': 9469186},
#  {'navn': 'Nonsense',
#   'artist': 'Sabrina Carpenter',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02700f7bf79c9f063ad0362bdf',
#   'plassering': 117,
#   'forrige_plassering': 117,
#   'topplassering': 17,
#   'topp_dato': '2023-01-26',
#   'uker_paa_listen': 51,
#   'antall_streams': 9451070},
#  {'navn': 'Ella Baila Sola',
#   'artist': 'Eslabon Armado',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02dfddf1cb31b85a6d28b7d91f',
#   'plassering': 118,
#   'forrige_plassering': 118,
#   'topplassering': 1,
#   'topp_dato': '2023-04-20',
#   'uker_paa_listen': 43,
#   'antall_streams': 9377942},
#  {'navn': '505',
#   'artist': 'Arctic Monkeys',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02b1f8da74f225fa1225cdface',
#   'plassering': 119,
#   'forrige_plassering': 119,
#   'topplassering': 43,
#   'topp_dato': '2022-10-13',
#   'uker_paa_listen': 105,
#   'antall_streams': 9364641},
#  {'navn': 'Every Breath You Take',
#   'artist': 'The Police',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02c8e97cafeb2acb85b21a777e',
#   'plassering': 120,
#   'forrige_plassering': 120,
#   'topplassering': 101,
#   'topp_dato': '2023-11-16',
#   'uker_paa_listen': 109,
#   'antall_streams': 9358087},
#  {'navn': 'Flashing Lights',
#   'artist': 'Kanye West',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0226f7f19c7f0381e56156c94a',
#   'plassering': 121,
#   'forrige_plassering': 121,
#   'topplassering': 121,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 16,
#   'antall_streams': 9355574},
#  {'navn': 'Heat Waves',
#   'artist': 'Glass Animals',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02712701c5e263efc8726b1464',
#   'plassering': 122,
#   'forrige_plassering': 122,
#   'topplassering': 1,
#   'topp_dato': '2022-01-27',
#   'uker_paa_listen': 155,
#   'antall_streams': 9341170},
#  {'navn': 'lovely (with Khalid)',
#   'artist': 'Billie Eilish',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e028a3f0a3ca7929dea23cd274c',
#   'plassering': 123,
#   'forrige_plassering': 123,
#   'topplassering': 24,
#   'topp_dato': '2018-06-14',
#   'uker_paa_listen': 299,
#   'antall_streams': 9339916},
#  {'navn': 'First Person Shooter (feat. J. Cole)',
#   'artist': 'Drake',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e027d384516b23347e92a587ed1',
#   'plassering': 124,
#   'forrige_plassering': 124,
#   'topplassering': 6,
#   'topp_dato': '2023-10-12',
#   'uker_paa_listen': 14,
#   'antall_streams': 9339260},
#  {'navn': 'Mr. Brightside',
#   'artist': 'The Killers',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02ccdddd46119a4ff53eaf1f5d',
#   'plassering': 125,
#   'forrige_plassering': 125,
#   'topplassering': 94,
#   'topp_dato': '2024-01-04',
#   'uker_paa_listen': 120,
#   'antall_streams': 9246920},
#  {'navn': 'Just the Way You Are',
#   'artist': 'Bruno Mars',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02f60070dce96a2c1b70cf6ff0',
#   'plassering': 126,
#   'forrige_plassering': 126,
#   'topplassering': 120,
#   'topp_dato': '2023-11-23',
#   'uker_paa_listen': 54,
#   'antall_streams': 9243312},
#  {'navn': 'Heather',
#   'artist': 'Conan Gray',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0288e3cda6d29b2552d4d6bc43',
#   'plassering': 127,
#   'forrige_plassering': 127,
#   'topplassering': 12,
#   'topp_dato': '2020-09-10',
#   'uker_paa_listen': 144,
#   'antall_streams': 9186636},
#  {'navn': 'Demons',
#   'artist': 'Imagine Dragons',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02407bd04707c463bbb3410737',
#   'plassering': 128,
#   'forrige_plassering': 128,
#   'topplassering': 119,
#   'topp_dato': '2023-10-05',
#   'uker_paa_listen': 59,
#   'antall_streams': 9186054},
#  {'navn': 'STAY (with Justin Bieber)',
#   'artist': 'The Kid LAROI',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02b4d59e6fa7e5e7cbc57ac33a',
#   'plassering': 129,
#   'forrige_plassering': 129,
#   'topplassering': 1,
#   'topp_dato': '2021-08-05',
#   'uker_paa_listen': 130,
#   'antall_streams': 9159548},
#  {'navn': 'Ghost',
#   'artist': 'Justin Bieber',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e6f407c7f3a0ec98845e4431',
#   'plassering': 130,
#   'forrige_plassering': 130,
#   'topplassering': 11,
#   'topp_dato': '2022-03-17',
#   'uker_paa_listen': 118,
#   'antall_streams': 9124466},
#  {'navn': 'Modo DND',
#   'artist': 'Xavi',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e028ba8f8c74b28ef7f25ae554a',
#   'plassering': 131,
#   'forrige_plassering': 131,
#   'topplassering': 131,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 2,
#   'antall_streams': 9108659},
#  {'navn': 'Sure Thing',
#   'artist': 'Miguel',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02d5a8395b0d80b8c48a5d851c',
#   'plassering': 132,
#   'forrige_plassering': 132,
#   'topplassering': 14,
#   'topp_dato': '2023-01-26',
#   'uker_paa_listen': 56,
#   'antall_streams': 9088623},
#  {'navn': 'Have You Ever Seen The Rain',
#   'artist': 'Creedence Clearwater Revival',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0251f311c2fb06ad2789e3ff91',
#   'plassering': 133,
#   'forrige_plassering': 133,
#   'topplassering': 133,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 21,
#   'antall_streams': 9074672},
#  {'navn': 'When I Was Your Man',
#   'artist': 'Bruno Mars',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02926f43e7cce571e62720fd46',
#   'plassering': 134,
#   'forrige_plassering': 134,
#   'topplassering': 72,
#   'topp_dato': '2023-02-09',
#   'uker_paa_listen': 71,
#   'antall_streams': 9067229},
#  {'navn': 'Dark Red',
#   'artist': 'Steve Lacy',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e023d2dfa42f771cd458b194979',
#   'plassering': 135,
#   'forrige_plassering': 135,
#   'topplassering': 66,
#   'topp_dato': '2021-09-16',
#   'uker_paa_listen': 108,
#   'antall_streams': 9050646},
#  {'navn': 'AMARGURA',
#   'artist': 'KAROL G',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0282de1ca074ae63cb18fce335',
#   'plassering': 136,
#   'forrige_plassering': 136,
#   'topplassering': 53,
#   'topp_dato': '2023-07-20',
#   'uker_paa_listen': 34,
#   'antall_streams': 9024218},
#  {'navn': '500lbs',
#   'artist': 'Lil Tecca',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02c4e6adea69105e6b6e214b96',
#   'plassering': 137,
#   'forrige_plassering': 137,
#   'topplassering': 89,
#   'topp_dato': '2023-11-23',
#   'uker_paa_listen': 12,
#   'antall_streams': 9009759},
#  {'navn': 'The Color Violet',
#   'artist': 'Tory Lanez',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e020c5f23cbf0b1ab7e37d0dc67',
#   'plassering': 138,
#   'forrige_plassering': 138,
#   'topplassering': 70,
#   'topp_dato': '2023-01-12',
#   'uker_paa_listen': 47,
#   'antall_streams': 8997328},
#  {'navn': 'Too Many Nights (feat. Don Toliver & with Future)',
#   'artist': 'Metro Boomin',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02c4fee55d7b51479627c31f89',
#   'plassering': 139,
#   'forrige_plassering': 139,
#   'topplassering': 33,
#   'topp_dato': '2022-12-08',
#   'uker_paa_listen': 44,
#   'antall_streams': 8970949},
#  {'navn': 'Take Me To Church',
#   'artist': 'Hozier',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e027a9bf5f82e32d33d4503fe7b',
#   'plassering': 140,
#   'forrige_plassering': 140,
#   'topplassering': 108,
#   'topp_dato': '2021-03-18',
#   'uker_paa_listen': 124,
#   'antall_streams': 8918353},
#  {'navn': 'Do I Wanna Know?',
#   'artist': 'Arctic Monkeys',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e024ae1c4c5c45aabe565499163',
#   'plassering': 141,
#   'forrige_plassering': 141,
#   'topplassering': 98,
#   'topp_dato': '2022-10-06',
#   'uker_paa_listen': 119,
#   'antall_streams': 8905425},
#  {'navn': 'august',
#   'artist': 'Taylor Swift',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0295f754318336a07e85ec59bc',
#   'plassering': 142,
#   'forrige_plassering': 142,
#   'topplassering': 11,
#   'topp_dato': '2020-07-30',
#   'uker_paa_listen': 48,
#   'antall_streams': 8904235},
#  {'navn': 'The Real Slim Shady',
#   'artist': 'Eminem',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02dbb3dd82da45b7d7f31b1b42',
#   'plassering': 143,
#   'forrige_plassering': 143,
#   'topplassering': 51,
#   'topp_dato': '2022-02-17',
#   'uker_paa_listen': 114,
#   'antall_streams': 8901838},
#  {'navn': 'ELOVRGA',
#   'artist': 'Alex Favela',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02c470398d2c6a0005706d9876',
#   'plassering': 144,
#   'forrige_plassering': 144,
#   'topplassering': 59,
#   'topp_dato': '2023-10-05',
#   'uker_paa_listen': 19,
#   'antall_streams': 8871190},
#  {'navn': 'Everybody Wants To Rule The World',
#   'artist': 'Tears For Fears',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0222463d6939fec9e17b2a6235',
#   'plassering': 145,
#   'forrige_plassering': 145,
#   'topplassering': 91,
#   'topp_dato': '2023-09-28',
#   'uker_paa_listen': 68,
#   'antall_streams': 8796160},
#  {'navn': 'LA FALDA',
#   'artist': 'Myke Towers',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02c75c054b6b209b0b91d818d8',
#   'plassering': 146,
#   'forrige_plassering': 146,
#   'topplassering': 146,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 2,
#   'antall_streams': 8763037},
#  {'navn': 'Sprinter',
#   'artist': 'Dave',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e3a09a9ae3f1fa102c110e60',
#   'plassering': 147,
#   'forrige_plassering': 147,
#   'topplassering': 6,
#   'topp_dato': '2023-07-20',
#   'uker_paa_listen': 32,
#   'antall_streams': 8742519},
#  {'navn': 'Cold Heart - PNAU Remix',
#   'artist': 'Elton John',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02eb842acacb3238b2bf3b8471',
#   'plassering': 148,
#   'forrige_plassering': 148,
#   'topplassering': 4,
#   'topp_dato': '2022-01-06',
#   'uker_paa_listen': 121,
#   'antall_streams': 8738399},
#  {'navn': 'wherever u r (ft. V of BTS)',
#   'artist': 'UMI',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0248bcaf5d476b6cb7c6277a7d',
#   'plassering': 149,
#   'forrige_plassering': 149,
#   'topplassering': 64,
#   'topp_dato': '2024-01-04',
#   'uker_paa_listen': 2,
#   'antall_streams': 8724709},
#  {'navn': 'In the End',
#   'artist': 'Linkin Park',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e2f039481babe23658fc719a',
#   'plassering': 150,
#   'forrige_plassering': 150,
#   'topplassering': 22,
#   'topp_dato': '2017-07-27',
#   'uker_paa_listen': 27,
#   'antall_streams': 8710820},
#  {'navn': 'Father Stretch My Hands Pt. 1',
#   'artist': 'Kanye West',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e022a7db835b912dc5014bd37f4',
#   'plassering': 151,
#   'forrige_plassering': 151,
#   'topplassering': 142,
#   'topp_dato': '2024-01-04',
#   'uker_paa_listen': 6,
#   'antall_streams': 8700586},
#  {'navn': "Let's Go 4",
#   'artist': 'Dj GBR',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02a2ab8a2b4cbbf685827eb835',
#   'plassering': 152,
#   'forrige_plassering': 152,
#   'topplassering': 85,
#   'topp_dato': '2023-11-16',
#   'uker_paa_listen': 17,
#   'antall_streams': 8696105},
#  {'navn': 'Dandelions',
#   'artist': 'Ruth B.',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0297e971f3e53475091dc8d707',
#   'plassering': 153,
#   'forrige_plassering': 153,
#   'topplassering': 34,
#   'topp_dato': '2022-03-31',
#   'uker_paa_listen': 125,
#   'antall_streams': 8682529},
#  {'navn': 'Trance (with Travis Scott & Young Thug)',
#   'artist': 'Metro Boomin',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02c4fee55d7b51479627c31f89',
#   'plassering': 154,
#   'forrige_plassering': 154,
#   'topplassering': 65,
#   'topp_dato': '2022-12-08',
#   'uker_paa_listen': 32,
#   'antall_streams': 8674653},
#  {'navn': 'Take on Me',
#   'artist': 'a-ha',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e8dd4db47e7177c63b0b7d53',
#   'plassering': 155,
#   'forrige_plassering': 155,
#   'topplassering': 83,
#   'topp_dato': '2023-11-23',
#   'uker_paa_listen': 22,
#   'antall_streams': 8645699},
#  {'navn': 'The Hills',
#   'artist': 'The Weeknd',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e027fcead687e99583072cc217b',
#   'plassering': 156,
#   'forrige_plassering': 156,
#   'topplassering': 52,
#   'topp_dato': '2021-02-11',
#   'uker_paa_listen': 90,
#   'antall_streams': 8627025},
#  {'navn': 'Perfect',
#   'artist': 'Ed Sheeran',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02ba5db46f4b838ef6027e6f96',
#   'plassering': 157,
#   'forrige_plassering': 157,
#   'topplassering': 4,
#   'topp_dato': '2017-11-30',
#   'uker_paa_listen': 354,
#   'antall_streams': 8600094},
#  {'navn': 'goosebumps',
#   'artist': 'Travis Scott',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02f54b99bf27cda88f4a7403ce',
#   'plassering': 158,
#   'forrige_plassering': 158,
#   'topplassering': 13,
#   'topp_dato': '2020-04-30',
#   'uker_paa_listen': 229,
#   'antall_streams': 8583832},
#  {'navn': 'Vois sur ton chemin - Techno Mix',
#   'artist': 'BENNETT',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e021b96e645016c4d431842aa93',
#   'plassering': 159,
#   'forrige_plassering': 159,
#   'topplassering': 85,
#   'topp_dato': '2023-10-26',
#   'uker_paa_listen': 12,
#   'antall_streams': 8582209},
#  {'navn': 'Lose Yourself',
#   'artist': 'Eminem',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec',
#   'plassering': 160,
#   'forrige_plassering': 160,
#   'topplassering': 44,
#   'topp_dato': '2022-02-24',
#   'uker_paa_listen': 128,
#   'antall_streams': 8566115},
#  {'navn': 'Runaway',
#   'artist': 'Kanye West',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02d9194aa18fa4c9362b47464f',
#   'plassering': 161,
#   'forrige_plassering': 161,
#   'topplassering': 161,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 4,
#   'antall_streams': 8564480},
#  {'navn': 'Closer Than This',
#   'artist': 'Jimin',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e3dbc03f538633dbb40adf37',
#   'plassering': 162,
#   'forrige_plassering': 162,
#   'topplassering': 65,
#   'topp_dato': '2023-12-28',
#   'uker_paa_listen': 3,
#   'antall_streams': 8554191},
#  {'navn': 'Super Shy',
#   'artist': 'NewJeans',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e023d98a0ae7c78a3a9babaf8af',
#   'plassering': 163,
#   'forrige_plassering': 163,
#   'topplassering': 9,
#   'topp_dato': '2023-07-27',
#   'uker_paa_listen': 26,
#   'antall_streams': 8521101},
#  {'navn': 'Here With Me',
#   'artist': 'd4vd',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0264fa1bda999f4fbd2b7c4bb7',
#   'plassering': 164,
#   'forrige_plassering': 164,
#   'topplassering': 14,
#   'topp_dato': '2023-02-02',
#   'uker_paa_listen': 62,
#   'antall_streams': 8520387},
#  {'navn': '"Slut!" (Taylor\'s Version) (From The Vault)',
#   'artist': 'Taylor Swift',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02904445d70d04eb24d6bb79ac',
#   'plassering': 165,
#   'forrige_plassering': 165,
#   'topplassering': 3,
#   'topp_dato': '2023-11-02',
#   'uker_paa_listen': 9,
#   'antall_streams': 8503739},
#  {'navn': 'Until I Found You (with Em Beihold) - Em Beihold Version',
#   'artist': 'Stephen Sanchez',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e022bf0876d42b90a8852ad6244',
#   'plassering': 166,
#   'forrige_plassering': 166,
#   'topplassering': 10,
#   'topp_dato': '2023-01-12',
#   'uker_paa_listen': 54,
#   'antall_streams': 8501736},
#  {'navn': 'Reggaeton Champagne',
#   'artist': 'Bellakath',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02ae47c3af718ff1301f80eb4f',
#   'plassering': 167,
#   'forrige_plassering': 167,
#   'topplassering': 78,
#   'topp_dato': '2023-11-16',
#   'uker_paa_listen': 14,
#   'antall_streams': 8495411},
#  {'navn': 'Last Night',
#   'artist': 'Morgan Wallen',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02705079df9a25a28b452c1fc9',
#   'plassering': 168,
#   'forrige_plassering': 168,
#   'topplassering': 14,
#   'topp_dato': '2023-03-09',
#   'uker_paa_listen': 47,
#   'antall_streams': 8466111},
#  {'navn': 'Not Allowed',
#   'artist': 'TV Girl',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0232f5fec7a879ed6ef28f0dfd',
#   'plassering': 169,
#   'forrige_plassering': 169,
#   'topplassering': 169,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 4,
#   'antall_streams': 8421630},
#  {'navn': 'MI EX TENÍA RAZÓN',
#   'artist': 'KAROL G',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02d026bf9d7780f6a1267b4d03',
#   'plassering': 170,
#   'forrige_plassering': 170,
#   'topplassering': 22,
#   'topp_dato': '2023-08-17',
#   'uker_paa_listen': 21,
#   'antall_streams': 8348655},
#  {'navn': 'golden hour',
#   'artist': 'JVKE',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02c2504e80ba2f258697ab2954',
#   'plassering': 171,
#   'forrige_plassering': 171,
#   'topplassering': 14,
#   'topp_dato': '2023-01-12',
#   'uker_paa_listen': 70,
#   'antall_streams': 8325257},
#  {'navn': 'Die For You (with Ariana Grande) - Remix',
#   'artist': 'The Weeknd',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e028ad8f5243d6534e03b656c8b',
#   'plassering': 172,
#   'forrige_plassering': 172,
#   'topplassering': 2,
#   'topp_dato': '2023-03-09',
#   'uker_paa_listen': 38,
#   'antall_streams': 8325087},
#  {'navn': 'Believer',
#   'artist': 'Imagine Dragons',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e025675e83f707f1d7271e5cf8a',
#   'plassering': 173,
#   'forrige_plassering': 173,
#   'topplassering': 16,
#   'topp_dato': '2017-06-29',
#   'uker_paa_listen': 358,
#   'antall_streams': 8322500},
#  {'navn': 'Money Trees',
#   'artist': 'Kendrick Lamar',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e022cd55246d935a8a77cb4859e',
#   'plassering': 174,
#   'forrige_plassering': 174,
#   'topplassering': 62,
#   'topp_dato': '2023-06-01',
#   'uker_paa_listen': 49,
#   'antall_streams': 8307476},
#  {'navn': 'Skyfall',
#   'artist': 'Adele',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e022737be35cc5245eef495be90',
#   'plassering': 175,
#   'forrige_plassering': 175,
#   'topplassering': 175,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 2,
#   'antall_streams': 8285666},
#  {'navn': 'Blank Space',
#   'artist': 'Taylor Swift',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0252b2a3824413eefe9e33817a',
#   'plassering': 176,
#   'forrige_plassering': 176,
#   'topplassering': 27,
#   'topp_dato': '2023-10-26',
#   'uker_paa_listen': 107,
#   'antall_streams': 8273163},
#  {'navn': 'Satranga (From "ANIMAL")',
#   'artist': 'Arijit Singh',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02021d7017f73387b008eab271',
#   'plassering': 177,
#   'forrige_plassering': 177,
#   'topplassering': 74,
#   'topp_dato': '2023-12-14',
#   'uker_paa_listen': 6,
#   'antall_streams': 8267266},
#  {'navn': 'La Bebe - Remix',
#   'artist': 'Yng Lvcas',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02a04be3ad7c8c67f4109111a9',
#   'plassering': 178,
#   'forrige_plassering': 178,
#   'topplassering': 3,
#   'topp_dato': '2023-04-20',
#   'uker_paa_listen': 43,
#   'antall_streams': 8253743},
#  {'navn': 'Es un Secreto',
#   'artist': 'Plan B',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e022bf273f977582e8f890192fe',
#   'plassering': 179,
#   'forrige_plassering': 179,
#   'topplassering': 157,
#   'topp_dato': '2023-07-27',
#   'uker_paa_listen': 17,
#   'antall_streams': 8228649},
#  {'navn': 'Creep',
#   'artist': 'Radiohead',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02df55e326ed144ab4f5cecf95',
#   'plassering': 180,
#   'forrige_plassering': 180,
#   'topplassering': 143,
#   'topp_dato': '2023-11-02',
#   'uker_paa_listen': 26,
#   'antall_streams': 8227388},
#  {'navn': 'LA PEOPLE',
#   'artist': 'Peso Pluma',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e022fb583ed96f8f35cbf2897ba',
#   'plassering': 181,
#   'forrige_plassering': 181,
#   'topplassering': 115,
#   'topp_dato': '2023-11-30',
#   'uker_paa_listen': 8,
#   'antall_streams': 8200560},
#  {'navn': 'Cupid - Twin Ver.',
#   'artist': 'FIFTY FIFTY',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e023013522be45e72a9b2514dd8',
#   'plassering': 182,
#   'forrige_plassering': 182,
#   'topplassering': 4,
#   'topp_dato': '2023-05-11',
#   'uker_paa_listen': 40,
#   'antall_streams': 8175865},
#  {'navn': 'Dreams - 2004 Remaster',
#   'artist': 'Fleetwood Mac',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e52a59a28efa4773dd2bfe1b',
#   'plassering': 183,
#   'forrige_plassering': 183,
#   'topplassering': 20,
#   'topp_dato': '2020-10-15',
#   'uker_paa_listen': 68,
#   'antall_streams': 8153272},
#  {'navn': 'Lil Boo Thang',
#   'artist': 'Paul Russell',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02811b8a1d3649f63af1d5fb65',
#   'plassering': 184,
#   'forrige_plassering': 184,
#   'topplassering': 173,
#   'topp_dato': '2024-01-04',
#   'uker_paa_listen': 2,
#   'antall_streams': 8129174},
#  {'navn': 'Diamonds',
#   'artist': 'Rihanna',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e027061b3d179b8b7363ffe1a50',
#   'plassering': 185,
#   'forrige_plassering': 185,
#   'topplassering': 77,
#   'topp_dato': '2023-02-16',
#   'uker_paa_listen': 14,
#   'antall_streams': 8072789},
#  {'navn': 'Godzilla (feat. Juice WRLD)',
#   'artist': 'Eminem',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e022f44aec83b20e40f3baef73c',
#   'plassering': 186,
#   'forrige_plassering': 186,
#   'topplassering': 4,
#   'topp_dato': '2020-01-23',
#   'uker_paa_listen': 85,
#   'antall_streams': 8055291},
#  {'navn': 'CRAZYZ',
#   'artist': 'Fuerza Regida',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02ad57982065339f7dc2058efe',
#   'plassering': 187,
#   'forrige_plassering': 187,
#   'topplassering': 187,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 1,
#   'antall_streams': 8044479},
#  {'navn': 'Iris',
#   'artist': 'The Goo Goo Dolls',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02eda9478c39a21e1cdc6609ca',
#   'plassering': 188,
#   'forrige_plassering': 188,
#   'topplassering': 124,
#   'topp_dato': '2022-06-02',
#   'uker_paa_listen': 24,
#   'antall_streams': 7997920},
#  {'navn': 'Bones',
#   'artist': 'Imagine Dragons',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02fc915b69600dce2991a61f13',
#   'plassering': 189,
#   'forrige_plassering': 189,
#   'topplassering': 26,
#   'topp_dato': '2022-10-20',
#   'uker_paa_listen': 91,
#   'antall_streams': 7939880},
#  {'navn': 'Me Leva Pra Casa / Escrito Nas Estrelas / Saudade - Ao Vivo',
#   'artist': 'Lauana Prado',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02a1e1725dc2508f171c909773',
#   'plassering': 190,
#   'forrige_plassering': 190,
#   'topplassering': 71,
#   'topp_dato': '2024-01-04',
#   'uker_paa_listen': 3,
#   'antall_streams': 7913303},
#  {'navn': 'Night Changes',
#   'artist': 'One Direction',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02d304ba2d71de306812eebaf4',
#   'plassering': 191,
#   'forrige_plassering': 191,
#   'topplassering': 108,
#   'topp_dato': '2022-08-18',
#   'uker_paa_listen': 69,
#   'antall_streams': 7896414},
#  {'navn': 'Wake Me Up',
#   'artist': 'Avicii',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02e14f11f796cef9f9a82691a7',
#   'plassering': 192,
#   'forrige_plassering': 192,
#   'topplassering': 13,
#   'topp_dato': '2018-04-26',
#   'uker_paa_listen': 94,
#   'antall_streams': 7896061},
#  {'navn': 'Save Your Tears (Remix) (with Ariana Grande) - Bonus Track',
#   'artist': 'The Weeknd',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02b5097b81179824803664aaaf',
#   'plassering': 193,
#   'forrige_plassering': 193,
#   'topplassering': 5,
#   'topp_dato': '2021-04-29',
#   'uker_paa_listen': 104,
#   'antall_streams': 7880696},
#  {'navn': 'LOU LOU',
#   'artist': 'Gabito Ballesteros',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e0238c5b1d6170ff3120bbbaf42',
#   'plassering': 194,
#   'forrige_plassering': 194,
#   'topplassering': 43,
#   'topp_dato': '2023-11-09',
#   'uker_paa_listen': 12,
#   'antall_streams': 7873124},
#  {'navn': 'Maps',
#   'artist': 'Maroon 5',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02442b53773d50e1b5369bb16c',
#   'plassering': 195,
#   'forrige_plassering': 195,
#   'topplassering': 190,
#   'topp_dato': '2023-11-23',
#   'uker_paa_listen': 4,
#   'antall_streams': 7855762},
#  {'navn': 'Those Eyes',
#   'artist': 'New West',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02aacd27a096e6e59ff555b46c',
#   'plassering': 196,
#   'forrige_plassering': 196,
#   'topplassering': 86,
#   'topp_dato': '2023-03-02',
#   'uker_paa_listen': 41,
#   'antall_streams': 7850959},
#  {'navn': 'Let Me Love You',
#   'artist': 'DJ Snake',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02212d776c31027c511f0ee3bc',
#   'plassering': 197,
#   'forrige_plassering': 197,
#   'topplassering': 4,
#   'topp_dato': '2016-12-29',
#   'uker_paa_listen': 49,
#   'antall_streams': 7839356},
#  {'navn': 'O Me Voy O Te Vas',
#   'artist': 'Natanael Cano',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02c1814d19b44c5e9df7ef33bd',
#   'plassering': 198,
#   'forrige_plassering': 198,
#   'topplassering': 198,
#   'topp_dato': '2024-01-11',
#   'uker_paa_listen': 1,
#   'antall_streams': 7838202},
#  {'navn': 'Jimmy Cooks (feat. 21 Savage)',
#   'artist': 'Drake',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e028dc0d801766a5aa6a33cbe37',
#   'plassering': 199,
#   'forrige_plassering': 199,
#   'topplassering': 7,
#   'topp_dato': '2022-06-23',
#   'uker_paa_listen': 77,
#   'antall_streams': 7807507},
#  {'navn': "That's What I Like",
#   'artist': 'Bruno Mars',
#   'bilde_url': 'https://i.scdn.co/image/ab67616d00001e02232711f7d66a1e19e89e28c5',
#   'plassering': 200,
#   'forrige_plassering': 200,
#   'topplassering': 6,
#   'topp_dato': '2017-04-06',
#   'uker_paa_listen': 95,
#   'antall_streams': 7711230}]

# %%
høyest = data[0]['uker_paa_listen']
høyest_sang = data[0]['navn']
for sang in data:
    if sang['uker_paa_listen'] > høyest:
        høyest = sang['uker_paa_listen']
        høyest_sang = sang['navn']
print(høyest_sang, høyest)
# Out:
# Believer 358

# %%
for sang in data:
    print(sang['artist'])
# Out:
# Xavi
# Tate McRae
# Jack Harlow
# Taylor Swift
# The Weeknd
# Mitski
# Noah Kahan
# Xavi
# Jung Kook
# Doja Cat
# Feid
# Peso Pluma
# The Weeknd
# Kenya Grace
# Arctic Monkeys
# Tyla
# Bad Bunny
# Jung Kook
# KAROL G
# Olivia Rodrigo
# Calle 24
# Doja Cat
# The Weeknd
# iñigo quintero
# Fuerza Regida
# Billie Eilish
# SZA
# Harry Styles
# David Kushner
# Vance Joy
# Dua Lipa
# Teddy Swims
# Sophie Ellis-Bextor
# JID
# Maluma
# Zach Bryan
# cassö
# Miley Cyrus
# Lord Huron
# The Weeknd
# Dua Lipa
# SZA
# Jung Kook
# The Neighbourhood
# The Weeknd
# Myke Towers
# Sabrina Carpenter
# Bad Bunny
# V
# Peso Pluma
# Taylor Swift
# Drake
# Grupo Frontera
# Tom Odell
# Tyler, The Creator
# Gunna
# Quevedo
# Tate McRae
# Peso Pluma
# Jimin
# David Guetta
# Drake
# Nicki Minaj
# Taylor Swift
# Taylor Swift
# Post Malone
# Travis Scott
# Grupo Frontera
# Rema
# OneRepublic
# Olivia Rodrigo
# Coldplay
# Vishal Mishra
# Coldplay
# Lewis Capaldi
# Kanye West
# Carin Leon
# Junior H
# Metro Boomin
# Bruno Mars
# Cigarettes After Sex
# Drake
# Feid
# Travis Scott
# Xavi
# OneRepublic
# Keane
# Anuv Jain
# Eminem
# The Weeknd
# Frank Ocean
# The Weeknd
# J. Cole
# JC NO BEAT
# Taylor Swift
# Manuel Turizo
# Arctic Monkeys
# Eugenio Esquivel
# The Walters
# TV Girl
# Eminem
# Rauw Alejandro
# Jere Klein
# LE SSERAFIM
# Rihanna
# Macklemore & Ryan Lewis
# Zach Bryan
# Kali Uchis
# Travis Scott
# Taylor Swift
# Lana Del Rey
# Hotel Ugly
# Adele
# Taylor Swift
# d4vd
# Luan Santana
# Sabrina Carpenter
# Eslabon Armado
# Arctic Monkeys
# The Police
# Kanye West
# Glass Animals
# Billie Eilish
# Drake
# The Killers
# Bruno Mars
# Conan Gray
# Imagine Dragons
# The Kid LAROI
# Justin Bieber
# Xavi
# Miguel
# Creedence Clearwater Revival
# Bruno Mars
# Steve Lacy
# KAROL G
# Lil Tecca
# Tory Lanez
# Metro Boomin
# Hozier
# Arctic Monkeys
# Taylor Swift
# Eminem
# Alex Favela
# Tears For Fears
# Myke Towers
# Dave
# Elton John
# UMI
# Linkin Park
# Kanye West
# Dj GBR
# Ruth B.
# Metro Boomin
# a-ha
# The Weeknd
# Ed Sheeran
# Travis Scott
# BENNETT
# Eminem
# Kanye West
# Jimin
# NewJeans
# d4vd
# Taylor Swift
# Stephen Sanchez
# Bellakath
# Morgan Wallen
# TV Girl
# KAROL G
# JVKE
# The Weeknd
# Imagine Dragons
# Kendrick Lamar
# Adele
# Taylor Swift
# Arijit Singh
# Yng Lvcas
# Plan B
# Radiohead
# Peso Pluma
# FIFTY FIFTY
# Fleetwood Mac
# Paul Russell
# Rihanna
# Eminem
# Fuerza Regida
# The Goo Goo Dolls
# Imagine Dragons
# Lauana Prado
# One Direction
# Avicii
# The Weeknd
# Gabito Ballesteros
# Maroon 5
# New West
# DJ Snake
# Natanael Cano
# Drake
# Bruno Mars

# %%
total = 0
antall = 0
for sang in data:
    total += sang['antall_streams']
    antall += 1
print(total / antall)
# Out:
# 11785697.48

# %%
total = 0
for sang in data:
    total += sang['antall_streams']

# %%
#oppgave 1.1
høyest = data[0]['uker_paa_listen']
høyest_sang = data[0]['navn']
for sang in data:
    if sang['uker_paa_listen'] > høyest:
        høyest = sang['uker_paa_listen']
        høyest_sang = sang['navn']
print('sangen med flest uker på topplista heter:', høyest_sang, 'med', høyest, 'uker')
# Out:
# sangen med flest uker på topplista heter: Believer med 358 uker

# %%
#oppgave1.2
total = 0
for sang in data:
    if sang['artist'] == 'Taylor Swift':
        total += sang['antall_streams']
print(total)
# Out:
# 120017297
